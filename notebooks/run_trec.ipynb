# %%
# Setup Environment & Clone Repository
import os
import sys

# 1. Clean up previous runs to ensure we pull the latest code
if os.path.exists("AutoPrompt-Lite"):
    # !rm -rf AutoPrompt-Lite

# 2. Clone YOUR repository (Make sure this matches your GitHub username)
REPO_URL = "https://github.com/imlydianna/AutoPrompt-Lite.git"
print(f"🔄 Cloning from: {REPO_URL}")
# !git clone $REPO_URL

# 3. Enter directory and install dependencies
os.chdir("AutoPrompt-Lite")
print("⏳ Installing dependencies...")
# !pip install -q -r requirements.txt

# 4. Add project to Python path
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())

print("✅ Setup Complete! Ready to run TREC Experiment.")
# Out:
# 🔄 Cloning from: https://github.com/imlydianna/AutoPrompt-Lite.git
# Cloning into 'AutoPrompt-Lite'...
# remote: Enumerating objects: 265, done.
# remote: Counting objects: 100% (265/265), done.
# remote: Compressing objects: 100% (188/188), done.
# remote: Total 265 (delta 138), reused 201 (delta 74), pack-reused 0 (from 0)
# Receiving objects: 100% (265/265), 91.16 KiB | 5.06 MiB/s, done.
# Resolving deltas: 100% (138/138), done.
# ⏳ Installing dependencies...
# ✅ Setup Complete! Ready to run TREC Experiment.

# %%
# Execute TREC Training Pipeline
# This uses Qwen-1.5B (Student) and Qwen-7B (Teacher)
# It will optimize: Instruction, Demos (Few-Shot), and Output Format.

from src.tasks.trec.train import run_training

# Start the experiment
run_training()
# Out:
# WARNING:adalflow.tracing.mlflow_integration:MLflow not available. Install with: pip install mlflow
# 🚀 INITIALIZING TREC EXPERIMENT (LocalLLM)...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# ...

# %%
# Inspect Optimized Prompts
import os

output_dir = "outputs/trec"
files = ["optimized_instruction.txt", "optimized_demos.txt"]

print(f"📂 Checking results in: {output_dir}\n")

for filename in files:
    path = os.path.join(output_dir, filename)
    if os.path.exists(path):
        print(f"✨ --- {filename.upper()} ---")
        with open(path, "r") as f:
            print(f.read())
        print("-" * 60 + "\n")
    else:
        print(f"❌ {filename} not found. Did training finish?")
